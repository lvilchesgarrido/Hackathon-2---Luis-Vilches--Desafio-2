# %%
# Crear el notebook completo en un archivo .ipynb
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.neural_network import MLPRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from xgboost import XGBRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Cargar datos
costos_df = pd.read_excel('Costos_Subprocesos.xlsx')
indicadores_df = pd.read_excel('Indicadores_Perforación.xlsx')

# Convertir las fechas a formato datetime
costos_df['Subproceso_Costo'] = pd.to_datetime(costos_df['Subproceso_Costo'])
indicadores_df['Mina/Rajo_Flota_Indicador'] = pd.to_datetime(indicadores_df['Mina/Rajo_Flota_Indicador'])

# Unir los DataFrames por la columna de fechas
df_unificado = pd.merge(costos_df, indicadores_df, left_on='Subproceso_Costo', right_on='Mina/Rajo_Flota_Indicador', how='inner')
df_unificado = df_unificado.drop(columns=['Mina/Rajo_Flota_Indicador'])

# Calcular la correlación entre todos los subprocesos y los indicadores
subprocesos_cols = costos_df.columns[1:]  # Excluyendo la columna de fecha
indicadores_cols = indicadores_df.columns[1:]  # Excluyendo la columna de fecha
correlation_matrix = df_unificado.corr()
correlation_filtered = correlation_matrix.loc[subprocesos_cols, indicadores_cols]
top_correlations = correlation_filtered.apply(lambda x: x.nlargest(3), axis=1)

# Dividir los datos en entrenamiento (2016-2021) y prueba (2022)
train_data = df_unificado[df_unificado['Subproceso_Costo'] < '2022-01-01']
test_data = df_unificado[df_unificado['Subproceso_Costo'] == '2022-01-01']

# %%
# Modelo 1: Linear Regression (Múltiple)
resultados_lr = {}
lr_model = LinearRegression()
imputer = SimpleImputer(strategy='mean')  # Imputar con la media

for subproceso in subprocesos_cols:
    indicadores_seleccionados = top_correlations.loc[subproceso].dropna().index.tolist()
    if len(indicadores_seleccionados) > 0:
        X_train = train_data[indicadores_seleccionados]
        y_train = train_data[subproceso]
        X_test = test_data[indicadores_seleccionados]
        
        # Imputar valores faltantes en X_train y X_test
        X_train = imputer.fit_transform(X_train)
        X_test = imputer.transform(X_test)
        
        # Entrenar el modelo
        lr_model.fit(X_train, y_train)
        
        # Realizar la predicción para el 2022
        y_pred_2022 = lr_model.predict(X_test)[0]
        costo_real_2022 = costos_df[costos_df['Subproceso_Costo'] == '2022-01-01'][subproceso].values[0]
        diferencia = y_pred_2022 - costo_real_2022
        diferencia_pct = (diferencia / costo_real_2022) * 100 if costo_real_2022 != 0 else 'N/A'
        resultados_lr[subproceso] = {'Predicción 2022': y_pred_2022, 'Costo Real 2022': costo_real_2022, 'Diferencia': diferencia, 'Diferencia %': diferencia_pct}

resultados_lr_df = pd.DataFrame(resultados_lr).T
print("Resultados para Linear Regression (Múltiple):")
print(resultados_lr_df)
# Out:
# Resultados para Linear Regression (Múltiple):
#                                         Predicción 2022  Costo Real 2022  \
# ADM OPERACIÓN Y GESTIÓN ESP              1695594.857562              0.0
# ADM OPERACIÓN Y GESTIÓN ESP SUR             8927.441737         30.27672
# ADM OPERACIÓN Y GESTIÓN MIR               160701.379119              0.0
# ADM OPERACIÓN Y GESTIÓN OXE              -464310.785967              0.0
# ADM OPERACIÓN Y GESTIÓN TC                170370.255256        906.14448
# ADM OPERACIÓN Y GESTIÓN TES SUR           116776.595251              0.0
# ADMINISTRACIÓN DESARROLLO MINA              1155.486889     881286.83064
# ADMINISTRACIÓN MINA                        -8620.083726    1780999.25816
# CARGUÍO                                 -1267324.063292     833630.60568
# CARGUÍO ENCUENTRO                           -15193.3529         262.9632
# CARGUÍO ESPERANZA                        2416230.982762              0.0
# CARGUÍO ESPERANZA SUR                       1592.648885              0.0
# CARGUÍO MIRADOR                           397333.316555              0.0
# CARGUÍO TESORO CENTRAL                    573414.545636     798743.62376
# CARGUÍO TESORO SUR                        235734.205388              0.0
# EQUIPOS  AUXILIARES                      -617243.184662     1148824.0217
# EQUIPOS DE SOPORTE (APOYO
# PERFORACIÓN MIRADOR                       -76434.976909      -50.008592
# PERFORACIÓN TESORO CENTRAL                 -6175.754649       -4.486075
# PERFORACIÓN TESORO NOR ESTE                   -3.344815             N/A
# PERFORACIÓN TESORO SUR                     51499.320884      674.547516
# SERVICIOS DE APOYO MINA                 -3820433.396779     -111.999074
# SERVICIOS TERCEROS ESP                    -13015.431585             N/A
# SERVICIOS TERCEROS ESP SUR              -5793432.916622      -52.757865
# SERVICIOS TERCEROS LLANO                            0.0             N/A
# SERVICIOS TERCEROS MIR                        99.902227       31.563233
# SERVICIOS TERCEROS OXE                  -7708983.812366      -51.612914
# SERVICIOS TERCEROS TC                      -1249.749006             N/A
# SERVICIOS Y EQUIPOS DE APOYO ENCUENTRO     -3622.084166             N/A
# SERVICIOS Y EQUIPOS DE APOYO ESP SUR      -12498.499282       -82.71458
# SERVICIOS Y EQUIPOS DE APOYO ESPERANZA   2912499.992358  1750683.438179
# SERVICIOS Y EQUIPOS DE APOYO MIRADOR      465578.785456             N/A
# SERVICIOS Y EQUIPOS DE APOYO TES SUR       220502.27762             N/A
# SERVICIOS Y EQUIPOS DE APOYO TESORO C.    679765.617342             N/A
# TRANSPORTE                             -19962756.404791     -115.232405
# TRANSPORTE ENCUENTRO                      -34610.247017             N/A
# TRANSPORTE ESPERANZA                    11135706.174991             N/A
# TRANSPORTE ESPERANZA SUR                    2177.378868             N/A
# TRANSPORTE MIRADOR                         525884.62081             N/A
# TRANSPORTE TESORO CENTRAL                1339805.597869             N/A
# TRANSPORTE TESORO SUR                     491954.856152             N/A
# TRONADURA ENCUENTRO                      -309290.822694      -28.812739
# TRONADURA ESPERANZA                       -629980.02666      -25.865817
# TRONADURA ESPERANZA SUR                 -1180518.847211      -95.852059
# TRONADURA MIRADOR                        -238119.495845      -69.740215
# TRONADURA TESORO CENTRAL                   -9987.202269       -3.262793
# TRONADURA TESORO NOR ESTE                           0.0             N/A
# TRONADURA TESORO SUR                       48959.532985       101.00432

# %%
# Modelo 2: Polynomial Regression (Regresión Polinómica)
resultados_pr = {}
for subproceso in subprocesos_cols:
    indicadores_seleccionados = top_correlations.loc[subproceso].dropna().index.tolist()
    if len(indicadores_seleccionados) > 0:
        X_train = train_data[indicadores_seleccionados]
        y_train = train_data[subproceso]
        X_test = test_data[indicadores_seleccionados]

        X_train = imputer.fit_transform(X_train)
        X_test = imputer.transform(X_test)
        
        poly = PolynomialFeatures(degree=2)
        X_train_poly = poly.fit_transform(X_train)
        X_test_poly = poly.transform(X_test)
        
        pr_model = LinearRegression()
        pr_model.fit(X_train_poly, y_train)
        y_pred_2022 = pr_model.predict(X_test_poly)[0]
        costo_real_2022 = costos_df[costos_df['Subproceso_Costo'] == '2022-01-01'][subproceso].values[0]
        diferencia = y_pred_2022 - costo_real_2022
        diferencia_pct = (diferencia / costo_real_2022) * 100 if costo_real_2022 != 0 else 'N/A'
        resultados_pr[subproceso] = {'Predicción 2022': y_pred_2022, 'Costo Real 2022': costo_real_2022, 'Diferencia': diferencia, 'Diferencia %': diferencia_pct}
resultados_pr_df = pd.DataFrame(resultados_pr).T
print("Resultados para Polynomial Regression (Regresión Polinómica):")
print(resultados_pr_df)
# Out:
# Resultados para Polynomial Regression (Regresión Polinómica):
#                                         Predicción 2022  Costo Real 2022  \
# ADM OPERACIÓN Y GESTIÓN ESP              1697587.861884              0.0
# ADM OPERACIÓN Y GESTIÓN ESP SUR             8927.441737         30.27672
# ADM OPERACIÓN Y GESTIÓN MIR              -212385.107717              0.0
# ADM OPERACIÓN Y GESTIÓN OXE               124481.000072              0.0
# ADM OPERACIÓN Y GESTIÓN TC                151904.044431        906.14448
# ADM OPERACIÓN Y GESTIÓN TES SUR           240401.098218              0.0
# ADMINISTRACIÓN DESARROLLO MINA             -2437.986474     881286.83064
# ADMINISTRACIÓN MINA                        37523.252883    1780999.25816
# CARGUÍO                                 -1246375.631874     833630.60568
# CARGUÍO ENCUENTRO                            -189.04909         262.9632
# CARGUÍO ESPERANZA                        1543453.978957              0.0
# CARGUÍO ESPERANZA SUR                       1592.648885              0.0
# CARGUÍO MIRADOR                           335162.874445              0.0
# CARGUÍO TESORO CENTRAL                    554679.873356     798743.62376
# CARGUÍO TESORO SUR                        292554.514265              0.0
# EQUIPOS  AUXILIARES                      -848241.158492     1148824.0217
# EQUIPOS DE SOPORTE (APOYO
# MINA STRIPPING ESPERANZA                     -59.096227             N/A
# PERFORACIÓN                              -1501192.42075     -133.219361
# PERFORACIÓN ENCUENTRO                       4419.559467             N/A
# PERFORACIÓN ESPERANZA                    1206125.179022      360.649288
# PERFORACIÓN ESPERANZA SUR                 -53480.590501      -95.713593
# PERFORACIÓN MIRADOR                       -76434.976909      -50.008592
# PERFORACIÓN TESORO CENTRAL                 -9532.781549       -6.924623
# PERFORACIÓN TESORO NOR ESTE                   -3.801206             N/A
# PERFORACIÓN TESORO SUR                     69023.553565      904.083118
# SERVICIOS DE APOYO MINA                 -3818280.882718     -111.935972
# SERVICIOS TERCEROS ESP                      4140.058495             N/A
# SERVICIOS TERCEROS ESP SUR             -18102799.845199     -164.853047
# SERVICIOS TERCEROS LLANO                            0.0             N/A
# SERVICIOS TERCEROS MIR                         161.6482       51.071331
# SERVICIOS TERCEROS OXE                  -5756113.030469      -38.538123
# SERVICIOS TERCEROS TC                        623.943915             N/A
# SERVICIOS Y EQUIPOS DE APOYO ENCUENTRO      2236.504939             N/A
# SERVICIOS Y EQUIPOS DE APOYO ESP SUR      -12498.499282       -82.71458
# SERVICIOS Y EQUIPOS DE APOYO ESPERANZA   7440984.119271  4472723.672288
# SERVICIOS Y EQUIPOS DE APOYO MIRADOR      404562.817635             N/A
# SERVICIOS Y EQUIPOS DE APOYO TES SUR      312324.351722             N/A
# SERVICIOS Y EQUIPOS DE APOYO TESORO C.    615971.490636             N/A
# TRANSPORTE                             -19847156.401575     -114.565119
# TRANSPORTE ENCUENTRO                        12178.54975             N/A
# TRANSPORTE ESPERANZA                    11135306.052383             N/A
# TRANSPORTE ESPERANZA SUR                    2177.378868             N/A
# TRANSPORTE MIRADOR                         525884.62081             N/A
# TRANSPORTE TESORO CENTRAL                1483462.403029             N/A
# TRANSPORTE TESORO SUR                    1168386.090987             N/A
# TRONADURA ENCUENTRO                       190655.824143       17.761007
# TRONADURA ESPERANZA                       -629980.02666      -25.865817
# TRONADURA ESPERANZA SUR                 -1180518.847211      -95.852059
# TRONADURA MIRADOR                        -238119.495845      -69.740215
# TRONADURA TESORO CENTRAL                    7957.839966        2.599806
# TRONADURA TESORO NOR ESTE                           0.0             N/A
# TRONADURA TESORO SUR                      208537.023421        430.2153

# %%
# Modelo 3: Neural Network (Redes Neuronales)
resultados_nn = {}
nn_model = MLPRegressor(hidden_layer_sizes=(100,), max_iter=1000, random_state=42)
for subproceso in subprocesos_cols:
    indicadores_seleccionados = top_correlations.loc[subproceso].dropna().index.tolist()
    if len(indicadores_seleccionados) > 0:
        X_train = train_data[indicadores_seleccionados]
        y_train = train_data[subproceso]
        X_test = test_data[indicadores_seleccionados]
        
        X_train = imputer.fit_transform(X_train)
        X_test = imputer.transform(X_test)
        
        nn_model.fit(X_train, y_train)
        y_pred_2022 = nn_model.predict(X_test)[0]
        costo_real_2022 = costos_df[costos_df['Subproceso_Costo'] == '2022-01-01'][subproceso].values[0]
        diferencia = y_pred_2022 - costo_real_2022
        diferencia_pct = (diferencia / costo_real_2022) * 100 if costo_real_2022 != 0 else 'N/A'
        resultados_nn[subproceso] = {'Predicción 2022': y_pred_2022, 'Costo Real 2022': costo_real_2022, 'Diferencia': diferencia, 'Diferencia %': diferencia_pct}
resultados_nn_df = pd.DataFrame(resultados_nn).T
print("Resultados para Neural Network (Redes Neuronales):")
print(resultados_nn_df)
# Out:
# C:\Users\Administrator\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\Administrator\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\Administrator\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\Administrator\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\Administrator\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\Administrator\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\Administrator\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\Administrator\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\Administrator\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\Administrator\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\Administrator\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\Administrator\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\Administrator\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\Administrator\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\Administrator\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\Administrator\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\Administrator\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\Administrator\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\Administrator\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\Administrator\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\Administrator\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\Administrator\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\Administrator\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\Administrator\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\Administrator\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\Administrator\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\Administrator\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\Administrator\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\Administrator\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\Administrator\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\Administrator\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\Administrator\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\Administrator\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\Administrator\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\Administrator\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\Administrator\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\Administrator\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\Administrator\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\Administrator\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\Administrator\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\Administrator\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\Administrator\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\Administrator\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\Administrator\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\Administrator\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\Administrator\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\Administrator\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\Administrator\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\Administrator\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Resultados para Neural Network (Redes Neuronales):
#                                        Predicción 2022  Costo Real 2022  \
# ADM OPERACIÓN Y GESTIÓN ESP                 160.202352              0.0
# ADM OPERACIÓN Y GESTIÓN ESP SUR             104.906048         30.27672
# ADM OPERACIÓN Y GESTIÓN MIR              126763.123398              0.0
# ADM OPERACIÓN Y GESTIÓN OXE                 172.420239              0.0
# ADM OPERACIÓN Y GESTIÓN TC               170542.468506        906.14448
# ADM OPERACIÓN Y GESTIÓN TES SUR            57997.53773              0.0
# ADMINISTRACIÓN DESARROLLO MINA             1195.874203     881286.83064
# ADMINISTRACIÓN MINA                      -14224.768586    1780999.25816
# CARGUÍO                                     -76.585097     833630.60568
# CARGUÍO ENCUENTRO                            56.128029         262.9632
# CARGUÍO ESPERANZA                           347.736227              0.0
# CARGUÍO ESPERANZA SUR                       103.399997              0.0
# CARGUÍO MIRADOR                           283070.58074              0.0
# CARGUÍO TESORO CENTRAL                    607618.13408     798743.62376
# CARGUÍO TESORO SUR                          152.436585              0.0
# EQUIPOS  AUXILIARES                        -5357.20386     1148824.0217
# EQUIPOS DE SOPORTE (APOYO
# MANTENIMIENTO MINA                      -2688377.707664     -97.64643
# MINA STRIPPING ESPERANZA                     -15.929304           N/A
# PERFORACIÓN                             -1131405.078599   -100.403559
# PERFORACIÓN ENCUENTRO                        104.581452           N/A
# PERFORACIÓN ESPERANZA                    -334264.699667    -99.950095
# PERFORACIÓN ESPERANZA SUR                 -55771.612924    -99.813809
# PERFORACIÓN MIRADOR                      -152738.503068    -99.931182
# PERFORACIÓN TESORO CENTRAL               -137498.980876    -99.879415
# PERFORACIÓN TESORO NOR ESTE                    0.218005           N/A
# PERFORACIÓN TESORO SUR                      -7482.95222    -98.013076
# SERVICIOS DE APOYO MINA                 -3411260.061147   -100.003829
# SERVICIOS TERCEROS ESP                        20.346188           N/A
# SERVICIOS TERCEROS ESP SUR             -10673669.747746    -97.199715
# SERVICIOS TERCEROS LLANO                     -15.975543           N/A
# SERVICIOS TERCEROS MIR                       132.042007     41.717514
# SERVICIOS TERCEROS OXE                 -14935878.307466     -99.99816
# SERVICIOS TERCEROS TC                         23.083947           N/A
# SERVICIOS Y EQUIPOS DE APOYO ENCUENTRO        74.563907           N/A
# SERVICIOS Y EQUIPOS DE APOYO ESP SUR      -15006.261331    -99.310851
# SERVICIOS Y EQUIPOS DE APOYO ESPERANZA       127.837072     76.841973
# SERVICIOS Y EQUIPOS DE APOYO MIRADOR      174873.292379           N/A
# SERVICIOS Y EQUIPOS DE APOYO TES SUR         270.076333           N/A
# SERVICIOS Y EQUIPOS DE APOYO TESORO C.    502334.170201           N/A
# TRANSPORTE                             -17329184.933381   -100.030457
# TRANSPORTE ENCUENTRO                          152.77052           N/A
# TRANSPORTE ESPERANZA                     3387098.950752           N/A
# TRANSPORTE ESPERANZA SUR                     103.915658           N/A
# TRANSPORTE MIRADOR                           105.215064           N/A
# TRANSPORTE TESORO CENTRAL                  800044.00186           N/A
# TRANSPORTE TESORO SUR                         261.93376           N/A
# TRONADURA ENCUENTRO                      -835223.953961    -77.807318
# TRONADURA ESPERANZA                     -2435464.578313    -99.995681
# TRONADURA ESPERANZA SUR                 -1231499.928396    -99.991461
# TRONADURA MIRADOR                        -341332.687852    -99.969198
# TRONADURA TESORO CENTRAL                 -103106.976457    -33.684785
# TRONADURA TESORO NOR ESTE                      0.098463           N/A
# TRONADURA TESORO SUR                      -48208.823685    -99.455594
# C:\Users\Administrator\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
# Modelo 4: Random Forest
resultados_rf = {}
rf_model = RandomForestRegressor(n_estimators=100, random_state=42)
for subproceso in subprocesos_cols:
    indicadores_seleccionados = top_correlations.loc[subproceso].dropna().index.tolist()
    if len(indicadores_seleccionados) > 0:
        X_train = train_data[indicadores_seleccionados]
        y_train = train_data[subproceso]
        X_test = test_data[indicadores_seleccionados]

        X_train = imputer.fit_transform(X_train)
        X_test = imputer.transform(X_test)
        
        rf_model.fit(X_train, y_train)
        y_pred_2022 = rf_model.predict(X_test)[0]
        costo_real_2022 = costos_df[costos_df['Subproceso_Costo'] == '2022-01-01'][subproceso].values[0]
        diferencia = y_pred_2022 - costo_real_2022
        diferencia_pct = (diferencia / costo_real_2022) * 100 if costo_real_2022 != 0 else 'N/A'
        resultados_rf[subproceso] = {'Predicción 2022': y_pred_2022, 'Costo Real 2022': costo_real_2022, 'Diferencia': diferencia, 'Diferencia %': diferencia_pct}
resultados_rf_df = pd.DataFrame(resultados_rf).T
print("Resultados para Random Forest:")
print(resultados_rf_df)
# Out:
# Resultados para Random Forest:
#                                         Predicción 2022  Costo Real 2022  \
# ADM OPERACIÓN Y GESTIÓN ESP              1685759.819836              0.0
# ADM OPERACIÓN Y GESTIÓN ESP SUR             8677.080201         30.27672
# ADM OPERACIÓN Y GESTIÓN MIR               102873.359933              0.0
# ADM OPERACIÓN Y GESTIÓN OXE                62603.649675              0.0
# ADM OPERACIÓN Y GESTIÓN TC                146882.249357        906.14448
# ADM OPERACIÓN Y GESTIÓN TES SUR           140206.573798              0.0
# ADMINISTRACIÓN DESARROLLO MINA              -312.705274     881286.83064
# ADMINISTRACIÓN MINA                        -2789.640699    1780999.25816
# CARGUÍO                                 -1235809.513256     833630.60568
# CARGUÍO ENCUENTRO                             77.167243         262.9632
# CARGUÍO ESPERANZA                        1991278.538857              0.0
# CARGUÍO ESPERANZA SUR                       1513.131645              0.0
# CARGUÍO MIRADOR                           196218.874135              0.0
# CARGUÍO TESORO CENTRAL                      769612.3623     798743.62376
# CARGUÍO TESORO SUR                          26545.36892              0.0
# EQUIPOS  AUXILIARES                      -826482.166743     1148824.0217
# EQUIPOS DE SOPORTE (APOYO
# EQUIPOS  AUXILIARES                     -1975306.188443     -171.941581
# EQUIPOS DE SOPORTE (APOYO)               -118299.174805      -125.57809
# MANTENIMIENTO MINA                      -1571590.816517      -57.082839
# MINA STRIPPING ESPERANZA                     -38.811211             N/A
# PERFORACIÓN                             -1441447.781993     -127.917481
# PERFORACIÓN ENCUENTRO                       4249.498837             N/A
# PERFORACIÓN ESPERANZA                    1204000.090484      360.013855
# PERFORACIÓN ESPERANZA SUR                 -53637.228544      -95.993926
# PERFORACIÓN MIRADOR                       -77743.140948      -50.864476
# PERFORACIÓN TESORO CENTRAL                 -6878.734774       -4.996721
# PERFORACIÓN TESORO NOR ESTE                         0.0             N/A
# PERFORACIÓN TESORO SUR                       3455.26112       45.257642
# SERVICIOS DE APOYO MINA                 -3821169.795498     -112.020662
# SERVICIOS TERCEROS ESP                              0.0             N/A
# SERVICIOS TERCEROS ESP SUR              -3051321.161143      -27.786839
# SERVICIOS TERCEROS LLANO                            0.0             N/A
# SERVICIOS TERCEROS MIR                       154.938568       48.951482
# SERVICIOS TERCEROS OXE                  -5712448.718999      -38.245783
# SERVICIOS TERCEROS TC                        387.976336             N/A
# SERVICIOS Y EQUIPOS DE APOYO ENCUENTRO      1912.548702             N/A
# SERVICIOS Y EQUIPOS DE APOYO ESP SUR      -12645.394182      -83.686724
# SERVICIOS Y EQUIPOS DE APOYO ESPERANZA   2879871.393526  1731070.614922
# SERVICIOS Y EQUIPOS DE APOYO MIRADOR      340948.498605             N/A
# SERVICIOS Y EQUIPOS DE APOYO TES SUR        34061.68955             N/A
# SERVICIOS Y EQUIPOS DE APOYO TESORO C.    797432.476062             N/A
# TRANSPORTE                             -20906675.590693     -120.681055
# TRANSPORTE ENCUENTRO                       10319.771149             N/A
# TRANSPORTE ESPERANZA                    10868896.178634             N/A
# TRANSPORTE ESPERANZA SUR                    1980.072662             N/A
# TRANSPORTE MIRADOR                        517287.579078             N/A
# TRANSPORTE TESORO CENTRAL                1900344.387611             N/A
# TRANSPORTE TESORO SUR                       98302.54215             N/A
# TRONADURA ENCUENTRO                      -145058.535279      -13.513281
# TRONADURA ESPERANZA                      -639880.209458      -26.272301
# TRONADURA ESPERANZA SUR                 -1183008.466788      -96.054204
# TRONADURA MIRADOR                        -239588.446695       -70.17044
# TRONADURA TESORO CENTRAL                  -55184.197206      -18.028536
# TRONADURA TESORO NOR ESTE                           0.0             N/A
# TRONADURA TESORO SUR                      -28668.932436      -59.144478

# %%
# Modelo 5: Gradient Boosting
resultados_gb = {}
gb_model = GradientBoostingRegressor(n_estimators=100, random_state=42)
for subproceso in subprocesos_cols:
    indicadores_seleccionados = top_correlations.loc[subproceso].dropna().index.tolist()
    if len(indicadores_seleccionados) > 0:
        X_train = train_data[indicadores_seleccionados]
        y_train = train_data[subproceso]
        X_test = test_data[indicadores_seleccionados]

        X_train = imputer.fit_transform(X_train)
        X_test = imputer.transform(X_test)
        
        gb_model.fit(X_train, y_train)
        y_pred_2022 = gb_model.predict(X_test)[0]
        costo_real_2022 = costos_df[costos_df['Subproceso_Costo'] == '2022-01-01'][subproceso].values[0]
        diferencia = y_pred_2022 - costo_real_2022
        diferencia_pct = (diferencia / costo_real_2022) * 100 if costo_real_2022 != 0 else 'N/A'
        resultados_gb[subproceso] = {'Predicción 2022': y_pred_2022, 'Costo Real 2022': costo_real_2022, 'Diferencia': diferencia, 'Diferencia %': diferencia_pct}
resultados_gb_df = pd.DataFrame(resultados_gb).T
print("Resultados para Gradient Boosting:")
print(resultados_gb_df)
# Out:
# Resultados para Gradient Boosting:
#                                         Predicción 2022  Costo Real 2022  \
# ADM OPERACIÓN Y GESTIÓN ESP              1697469.166562              0.0
# ADM OPERACIÓN Y GESTIÓN ESP SUR             8927.441737         30.27672
# ADM OPERACIÓN Y GESTIÓN MIR               202161.792145              0.0
# ADM OPERACIÓN Y GESTIÓN OXE                57765.155777              0.0
# ADM OPERACIÓN Y GESTIÓN TC                134714.453758        906.14448
# ADM OPERACIÓN Y GESTIÓN TES SUR           147149.886603              0.0
# ADMINISTRACIÓN DESARROLLO MINA              -232.833855     881286.83064
# ADMINISTRACIÓN MINA                         -616.854245    1780999.25816
# CARGUÍO                                 -1245558.896975     833630.60568
# CARGUÍO ENCUENTRO                            -26.850857         262.9632
# CARGUÍO ESPERANZA                        2131997.628287              0.0
# CARGUÍO ESPERANZA SUR                       1592.648885              0.0
# CARGUÍO MIRADOR                            14619.289034              0.0
# CARGUÍO TESORO CENTRAL                    822710.851005     798743.62376
# CARGUÍO TESORO SUR                          1128.634709              0.0
# EQUIPOS  AUXILIARES                      -767691.266904     1148824.0217
# EQUIPOS DE SOPORTE (APOYO
# CARGUÍO TESORO SUR                          1128.634709             N/A
# EQUIPOS  AUXILIARES                     -1916515.288604     -166.824096
# EQUIPOS DE SOPORTE (APOYO)               -121165.894832     -128.621198
# MANTENIMIENTO MINA                      -1280298.556805      -46.502611
# MINA STRIPPING ESPERANZA                            0.0             N/A
# PERFORACIÓN                             -1419187.576629     -125.942057
# PERFORACIÓN ENCUENTRO                       4419.559467             N/A
# PERFORACIÓN ESPERANZA                    1205639.695337      360.504121
# PERFORACIÓN ESPERANZA SUR                 -53480.590501      -95.713593
# PERFORACIÓN MIRADOR                       -76434.976909      -50.008592
# PERFORACIÓN TESORO CENTRAL                  -9014.07548       -6.547835
# PERFORACIÓN TESORO NOR ESTE                    0.000192             N/A
# PERFORACIÓN TESORO SUR                     -6509.082514      -85.257152
# SERVICIOS DE APOYO MINA                  -3818935.68058     -111.955168
# SERVICIOS TERCEROS ESP                       192.481754             N/A
# SERVICIOS TERCEROS ESP SUR               -618073.324112       -5.628481
# SERVICIOS TERCEROS LLANO                            0.0             N/A
# SERVICIOS TERCEROS MIR                       169.923066       53.685703
# SERVICIOS TERCEROS OXE                  -8315057.545965      -55.670677
# SERVICIOS TERCEROS TC                        272.358559             N/A
# SERVICIOS Y EQUIPOS DE APOYO ENCUENTRO      1729.171946             N/A
# SERVICIOS Y EQUIPOS DE APOYO ESP SUR      -12498.499282       -82.71458
# SERVICIOS Y EQUIPOS DE APOYO ESPERANZA   2655184.808546  1596013.075304
# SERVICIOS Y EQUIPOS DE APOYO MIRADOR      594184.024479             N/A
# SERVICIOS Y EQUIPOS DE APOYO TES SUR        2010.537553             N/A
# SERVICIOS Y EQUIPOS DE APOYO TESORO C.    819009.066446             N/A
# TRANSPORTE                             -20087122.174725      -115.95029
# TRANSPORTE ENCUENTRO                        8886.834984             N/A
# TRANSPORTE ESPERANZA                    10399396.442174             N/A
# TRANSPORTE ESPERANZA SUR                    2177.378868             N/A
# TRANSPORTE MIRADOR                         525884.62081             N/A
# TRANSPORTE TESORO CENTRAL                2030791.732644             N/A
# TRANSPORTE TESORO SUR                      26016.019108             N/A
# TRONADURA ENCUENTRO                        -150491.1327      -14.019367
# TRONADURA ESPERANZA                       -629980.02666      -25.865817
# TRONADURA ESPERANZA SUR                 -1180518.847211      -95.852059
# TRONADURA MIRADOR                        -238119.495845      -69.740215
# TRONADURA TESORO CENTRAL                  -41964.194997      -13.709595
# TRONADURA TESORO NOR ESTE                           0.0             N/A
# TRONADURA TESORO SUR                      -46254.507862      -95.423808

# %%
# Modelo 6: XGBoost
resultados_xgb = {}
xgb_model = XGBRegressor(n_estimators=100, random_state=42)
for subproceso in subprocesos_cols:
    indicadores_seleccionados = top_correlations.loc[subproceso].dropna().index.tolist()
    if len(indicadores_seleccionados) > 0:
        X_train = train_data[indicadores_seleccionados]
        y_train = train_data[subproceso]
        X_test = test_data[indicadores_seleccionados]

        X_train = imputer.fit_transform(X_train)
        X_test = imputer.transform(X_test)

        xgb_model.fit(X_train, y_train)
        y_pred_2022 = xgb_model.predict(X_test)[0]
        costo_real_2022 = costos_df[costos_df['Subproceso_Costo'] == '2022-01-01'][subproceso].values[0]
        diferencia = y_pred_2022 - costo_real_2022
        diferencia_pct = (diferencia / costo_real_2022) * 100 if costo_real_2022 != 0 else 'N/A'
        resultados_xgb[subproceso] = {'Predicción 2022': y_pred_2022, 'Costo Real 2022': costo_real_2022, 'Diferencia': diferencia, 'Diferencia %': diferencia_pct}
resultados_xgb_df = pd.DataFrame(resultados_xgb).T
print("Resultados para XGBoost:")
print(resultados_xgb_df)
# Out:
# Resultados para XGBoost:
#                                        Predicción 2022  Costo Real 2022  \
# ADM OPERACIÓN Y GESTIÓN ESP                 1697472.25              0.0
# ADM OPERACIÓN Y GESTIÓN ESP SUR            8927.441406         30.27672
# ADM OPERACIÓN Y GESTIÓN MIR               -3336.699951              0.0
# ADM OPERACIÓN Y GESTIÓN OXE               59947.613281              0.0
# ADM OPERACIÓN Y GESTIÓN TC               107907.359375        906.14448
# ADM OPERACIÓN Y GESTIÓN TES SUR           136675.46875              0.0
# ADMINISTRACIÓN DESARROLLO MINA             -234.681595     881286.83064
# ADMINISTRACIÓN MINA                        -586.695312    1780999.25816
# CARGUÍO                                     -1245149.0     833630.60568
# CARGUÍO ENCUENTRO                            79.181519         262.9632
# CARGUÍO ESPERANZA                            1664755.0              0.0
# CARGUÍO ESPERANZA SUR                      1592.648926              0.0
# CARGUÍO MIRADOR                                0.00396              0.0
# CARGUÍO TESORO CENTRAL                     735932.5625     798743.62376
# CARGUÍO TESORO SUR                            0.005068              0.0
# EQUIPOS  AUXILIARES                         -779863.75     1148824.0217
# EQUIPOS DE SOPORTE (APOYO)               -24841.955078     94203.674547
# MANTENIMIENTO MINA                          1029879.25    2753175.61454
# MINA STRIPPING ESPERANZA                     -0.000026              0.0
# PERFORACIÓN                              -511878.71875   1126857.545153
# PERFORACIÓN ENCUENTRO                       4419.55957              0.0
# PERFORACIÓN ESPERANZA                      1539763.875     334431.59872
# PERFORACIÓN ESPERANZA SUR                  2395.057861      55875.64824
# PERFORACIÓN MIRADOR                       76408.710938     152843.68776
# PERFORACIÓN TESORO CENTRAL               128138.914062     137664.98448
# PERFORACIÓN TESORO NOR ESTE                   0.000024              0.0
# PERFORACIÓN TESORO SUR                        0.200725       7634.64688
# SERVICIOS DE APOYO MINA                   -407971.1875   3411129.441513
# SERVICIOS TERCEROS ESP                       -0.041566              0.0
# SERVICIOS TERCEROS ESP SUR                  11186444.0   10981173.94088
# SERVICIOS TERCEROS LLANO                           0.0              0.0
# SERVICIOS TERCEROS MIR                      567.519226        316.51456
# SERVICIOS TERCEROS OXE                      3169559.75   14936153.07776
# SERVICIOS TERCEROS TC                       327.760529              0.0
# SERVICIOS Y EQUIPOS DE APOYO ENCUENTRO     1810.374023              0.0
# SERVICIOS Y EQUIPOS DE APOYO ESP SUR        2611.89502      15110.39448
# SERVICIOS Y EQUIPOS DE APOYO ESPERANZA      2668198.25         166.3636
# SERVICIOS Y EQUIPOS DE APOYO MIRADOR     -14599.275391              0.0
# SERVICIOS Y EQUIPOS DE APOYO TES SUR        58562.3125              0.0
# SERVICIOS Y EQUIPOS DE APOYO TESORO C
N/A
# SERVICIOS Y EQUIPOS DE APOYO TESORO C.       852137.875             N/A
# TRANSPORTE                             -19628527.255433     -113.303111
# TRANSPORTE ENCUENTRO                        9349.075195             N/A
# TRANSPORTE ESPERANZA                         10640743.0             N/A
# TRANSPORTE ESPERANZA SUR                    2177.378662             N/A
# TRANSPORTE MIRADOR                           525884.625             N/A
# TRANSPORTE TESORO CENTRAL                     1883729.5             N/A
# TRANSPORTE TESORO SUR                      55440.839844             N/A
# TRONADURA ENCUENTRO                       -238300.04092       -22.19942
# TRONADURA ESPERANZA                       -629980.02224      -25.865817
# TRONADURA ESPERANZA SUR                    -1180518.846      -95.852059
# TRONADURA MIRADOR                        -238119.496625      -69.740216
# TRONADURA TESORO CENTRAL                    -42435.5535      -13.863587
# TRONADURA TESORO NOR ESTE                           0.0             N/A
# TRONADURA TESORO SUR                      -30355.583094      -62.624066

# %%
# Comparación de resultados
resultados_totales = {
    'Linear Regression (Múltiple)': resultados_lr_df,
    'Polynomial Regression': resultados_pr_df,
    'Neural Network': resultados_nn_df,
    'Random Forest': resultados_rf_df,
    'Gradient Boosting': resultados_gb_df,
    'XGBoost': resultados_xgb_df
}
for modelo, resultados in resultados_totales.items():
    print(f"Resumen para {modelo}:")
    print(resultados[['Diferencia %']])
    print("\n\n")
# Out:
# Resumen para Linear Regression (Múltiple):
#                                           Diferencia %
# ADM OPERACIÓN Y GESTIÓN ESP                        N/A
# ADM OPERACIÓN Y GESTIÓN ESP SUR           29386.158796
# ADM OPERACIÓN Y GESTIÓN MIR                        N/A
# ADM OPERACIÓN Y GESTIÓN OXE                        N/A
# ADM OPERACIÓN Y GESTIÓN TC                 18701.66563
# ADM OPERACIÓN Y GESTIÓN TES SUR                    N/A
# ADMINISTRACIÓN DESARROLLO MINA              -99.868886
# ADMINISTRACIÓN MINA                        -100.484003
# CARGUÍO                                    -252.024656
# CARGUÍO ENCUENTRO                         -5877.748712
# CARGUÍO ESPERANZA                                  N/A
# CARGUÍO ESPERANZA SUR                              N/A
# CARGUÍO MIRADOR                                    N/A
# CARGUÍO TESORO CENTRAL                      -28.210438
# CARGUÍO TESORO SUR                                 N/A
# EQUIPOS  AUXILIARES                        -153.728262
# EQUIPOS DE SOPORTE (APOYO)                 -128.352908
# MANTENIMIENTO MINA                         -130.674071
# MINA STRIPPING ESPERANZA                           N/A
# PERFORACIÓN                                -133.684471
# PERFORACIÓN ENCUENTRO                              N/A
# PERFORACIÓN ESPERANZA                       358.054568
# PERFORACIÓN ESPERANZA SUR                   -95.713593
# PERFORACIÓN MIRADOR                         -50.008592
# PERFORACIÓN TESORO CENTRAL                   -4.486075
# PERFORACIÓN TESORO NOR ESTE                        N/A
# PERFORACIÓN TESORO SUR                      674.547516
# SERVICIOS DE APOYO MINA                    -111.999074
# SERVICIOS TERCEROS ESP                             N/A
# SERVICIOS TERCEROS ESP SUR                  -52.757865
# SERVICIOS TERCEROS LLANO                           N/A
# SERVICIOS TERCEROS MIR                       31.563233
# SERVICIOS TERCEROS OXE                      -51.612914
# SERVICIOS TERCEROS TC                              N/A
# SERVICIOS Y EQUIPOS DE APOYO ENCUENTRO             N/A
# SERVICIOS Y EQUIPOS DE APOYO ESP SUR         -82.71458
# SERVICIOS Y EQUIPOS DE APOYO ESPERANZA  1750683.438179
# SERVICIOS Y EQUIPOS DE APOYO MIRADOR               N/A
# SERVICIOS Y EQUIPOS DE APOYO TES SUR               N/A
# SERVICIOS Y EQUIPOS DE APOYO TESORO C.             N/A
# TRANSPORTE                                 -115.232405
# TRANSPORTE ENCUENTRO                               N/A
# TRANSPORTE ESPERANZA                               N/A
# TRANSPORTE ESPERANZA SUR                           N/A
# TRANSPORTE MIRADOR                                 N/A
# TRANSPORTE TESORO CENTRAL                          N/A
# TRANSPORTE TESORO SUR                              N/A
# TRONADURA ENCUENTRO                         -28.812739
# TRONADURA ESPERANZA                         -25.865817
# TRONADURA ESPERANZA SUR                     -95.852059
# TRONADURA MIRADOR                           -69.740215
# TRONADURA TESORO CENTRAL                     -3.262793
# TRONADURA TESORO NOR ESTE                          N/A
# TRONADURA TESORO SUR                         101.00432
#
#
#
# Resumen para Polynomial Regression:
#                                           Diferencia %
# ADM OPERACIÓN Y GESTIÓN ESP                        N/A
# ADM OPERACIÓN Y GESTIÓN ESP SUR           29386.158796
# ADM OPERACIÓN Y GESTIÓN MIR                        N/A
# ADM OPERACIÓN Y GESTIÓN OXE                        N/A
# ADM OPERACIÓN Y GESTIÓN TC                16663.777497
# ADM OPERACIÓN Y GESTIÓN TES SUR                    N/A
# ADMINISTRACIÓN DESARROLLO MINA             -100.276639
# ADMINISTRACIÓN MINA                         -97.893135
# CARGUÍO                                    -249.511741
# CARGUÍO ENCUENTRO                          -171.891843
# CARGUÍO ESPERANZA                                  N/A
# CARGUÍO ESPERANZA SUR                              N/A
# CARGUÍO MIRADOR                                    N/A
# CARGUÍO TESORO CENTRAL                      -30.555956
# CARGUÍO TESORO SUR                                 N/A
# EQUIPOS  AUXILIARES                        -173.835604
# EQUIPOS DE SOPORTE (APOYO)                 -127.366771
# MANTENIMIENTO MINA                          368.836718
# MINA STRIPPING ESPERANZA                           N/A
# PERFORACIÓN                                -133.219361
# PERFORACIÓN ENCUENTRO                              N/A
# PERFORACIÓN ESPERANZA                       360.649288
# PERFORACIÓN ESPERANZA SUR                   -95.713593
# PERFORACIÓN MIRADOR                         -50.008592
# PERFORACIÓN TESORO CENTRAL                   -6.924623
# PERFORACIÓN TESORO NOR ESTE                        N/A
# PERFORACIÓN TESORO SUR                      904.083118
# SERVICIOS DE APOYO MINA                    -111.935972
# SERVICIOS TERCEROS ESP                             N/A
# SERVICIOS TERCEROS ESP SUR                 -164.853047
# SERVICIOS TERCEROS LLANO                           N/A
# SERVICIOS TERCEROS MIR                       51.071331
# SERVICIOS TERCEROS OXE                      -38.538123
# SERVICIOS TERCEROS TC                              N/A
# SERVICIOS Y EQUIPOS DE APOYO ENCUENTRO             N/A
# SERVICIOS Y EQUIPOS DE APOYO ESP SUR         -82.71458
# SERVICIOS Y EQUIPOS DE APOYO ESPERANZA  4472723.672288
# SERVICIOS Y EQUIPOS DE APOYO MIRADOR               N/A
# SERVICIOS Y EQUIPOS DE APOYO TES SUR               N/A
# SERVICIOS Y EQUIPOS DE APOYO TESORO C.             N/A
# TRANSPORTE                                 -114.565119
# TRANSPORTE ENCUENTRO                               N/A
# TRANSPORTE ESPERANZA                               N/A
# TRANSPORTE ESPERANZA SUR                           N/A
# TRANSPORTE MIRADOR                                 N/A
# TRANSPORTE TESORO CENTRAL                          N/A
# TRANSPORTE TESORO SUR                              N/A
# TRONADURA ENCUENTRO                          17.761007
# TRONADURA ESPERANZA                         -25.865817
# TRONADURA ESPERANZA SUR                     -95.852059
# TRONADURA MIRADOR                           -69.740215
# TRONADURA TESORO CENTRAL                      2.599806
# TRONADURA TESORO NOR ESTE                          N/A
# TRONADURA TESORO SUR                          430.2153
#
#
#
# Resumen para Neural Network:
#                                         Diferencia %
# ADM OPERACIÓN Y GESTIÓN ESP                      N/A
# ADM OPERACIÓN Y GESTIÓN ESP SUR           246.490794
# ADM OPERACIÓN Y GESTIÓN MIR                      N/A
# ADM OPERACIÓN Y GESTIÓN OXE                      N/A
# ADM OPERACIÓN Y GESTIÓN TC              18720.670684
# ADM OPERACIÓN Y GESTIÓN TES SUR                  N/A
# ADMINISTRACIÓN DESARROLLO MINA            -99.864304
# ADMINISTRACIÓN MINA                      -100.798696
# CARGUÍO                                  -100.009187
# CARGUÍO ENCUENTRO                         -78.655557
# CARGUÍO ESPERANZA                                N/A
# CARGUÍO ESPERANZA SUR                            N/A
# CARGUÍO MIRADOR                                  N/A
# CARGUÍO TESORO CENTRAL                    -23.928265
# CARGUÍO TESORO SUR                               N/A
# EQUIPOS  AUXILIARES                      -100.466321
# EQUIPOS DE SOPORTE (APOYO)               -109.572107
# MANTENIMIENTO MINA                         -97.64643
# MINA STRIPPING ESPERANZA                         N/A
# PERFORACIÓN                              -100.403559
# PERFORACIÓN ENCUENTRO                            N/A
# PERFORACIÓN ESPERANZA                     -99.950095
# PERFORACIÓN ESPERANZA SUR                 -99.813809
# PERFORACIÓN MIRADOR                       -99.931182
# PERFORACIÓN TESORO CENTRAL                -99.879415
# PERFORACIÓN TESORO NOR ESTE                      N/A
# PERFORACIÓN TESORO SUR                    -98.013076
# SERVICIOS DE APOYO MINA                  -100.003829
# SERVICIOS TERCEROS ESP                           N/A
# SERVICIOS TERCEROS ESP SUR                -97.199715
# SERVICIOS TERCEROS LLANO                         N/A
# SERVICIOS TERCEROS MIR                     41.717514
# SERVICIOS TERCEROS OXE                     -99.99816
# SERVICIOS TERCEROS TC                            N/A
# SERVICIOS Y EQUIPOS DE APOYO ENCUENTRO           N/A
# SERVICIOS Y EQUIPOS DE APOYO ESP SUR      -99.310851
# SERVICIOS Y EQUIPOS DE APOYO ESPERANZA     76.841973
# SERVICIOS Y EQUIPOS DE APOYO MIRADOR             N/A
# SERVICIOS Y EQUIPOS DE APOYO TES SUR             N/A
# SERVICIOS Y EQUIPOS DE APOYO TESORO C.           N/A
# TRANSPORTE                               -100.030457
# TRANSPORTE ENCUENTRO                             N/A
# TRANSPORTE ESPERANZA                             N/A
# TRANSPORTE ESPERANZA SUR                         N/A
# TRANSPORTE MIRADOR                               N/A
# TRANSPORTE TESORO CENTRAL                        N/A
# TRANSPORTE TESORO SUR                            N/A
# TRONADURA ENCUENTRO                       -77.807318
# TRONADURA ESPERANZA                       -99.995681
# TRONADURA ESPERANZA SUR                   -99.991461
# TRONADURA MIRADOR                         -99.969198
# TRONADURA TESORO CENTRAL                  -33.684785
# TRONADURA TESORO NOR ESTE                        N/A
# TRONADURA TESORO SUR                      -99.455594
#
#
#
# Resumen para Random Forest:
#                                           Diferencia %
# ADM OPERACIÓN Y GESTIÓN ESP                        N/A
# ADM OPERACIÓN Y GESTIÓN ESP SUR           28559.247767
# ADM OPERACIÓN Y GESTIÓN MIR                        N/A
# ADM OPERACIÓN Y GESTIÓN OXE                        N/A
# ADM OPERACIÓN Y GESTIÓN TC                16109.583858
# ADM OPERACIÓN Y GESTIÓN TES SUR                    N/A
# ADMINISTRACIÓN DESARROLLO MINA             -100.035483
# ADMINISTRACIÓN MINA                        -100.156633
# CARGUÍO                                    -248.244259
# CARGUÍO ENCUENTRO                           -70.654737
# CARGUÍO ESPERANZA                                  N/A
# CARGUÍO ESPERANZA SUR                              N/A
# CARGUÍO MIRADOR                                    N/A
# CARGUÍO TESORO CENTRAL                       -3.647135
# CARGUÍO TESORO SUR                                 N/A
# EQUIPOS  AUXILIARES                        -171.941581
# EQUIPOS DE SOPORTE (APOYO)                  -125.57809
# MANTENIMIENTO MINA                          -57.082839
# MINA STRIPPING ESPERANZA                           N/A
# PERFORACIÓN                                -127.917481
# PERFORACIÓN ENCUENTRO                              N/A
# PERFORACIÓN ESPERANZA                       360.013855
# PERFORACIÓN ESPERANZA SUR                   -95.993926
# PERFORACIÓN MIRADOR                         -50.864476
# PERFORACIÓN TESORO CENTRAL                   -4.996721
# PERFORACIÓN TESORO NOR ESTE                        N/A
# PERFORACIÓN TESORO SUR                       45.257642
# SERVICIOS DE APOYO MINA                    -112.020662
# SERVICIOS TERCEROS ESP                             N/A
# SERVICIOS TERCEROS ESP SUR                  -27.786839
# SERVICIOS TERCEROS LLANO                           N/A
# SERVICIOS TERCEROS MIR                       48.951482
# SERVICIOS TERCEROS OXE                      -38.245783
# SERVICIOS TERCEROS TC                              N/A
# SERVICIOS Y EQUIPOS DE APOYO ENCUENTRO             N/A
# SERVICIOS Y EQUIPOS DE APOYO ESP SUR        -83.686724
# SERVICIOS Y EQUIPOS DE APOYO ESPERANZA  1731070.614922
# SERVICIOS Y EQUIPOS DE APOYO MIRADOR               N/A
# SERVICIOS Y EQUIPOS DE APOYO TES SUR               N/A
# SERVICIOS Y EQUIPOS DE APOYO TESORO C.             N/A
# TRANSPORTE                                 -120.681055
# TRANSPORTE ENCUENTRO                               N/A
# TRANSPORTE ESPERANZA                               N/A
# TRANSPORTE ESPERANZA SUR                           N/A
# TRANSPORTE MIRADOR                                 N/A
# TRANSPORTE TESORO CENTRAL                          N/A
# TRANSPORTE TESORO SUR                              N/A
# TRONADURA ENCUENTRO                         -13.513281
# TRONADURA ESPERANZA                         -26.272301
# TRONADURA ESPERANZA SUR                     -96.054204
# TRONADURA MIRADOR                            -70.17044
# TRONADURA TESORO CENTRAL                    -18.028536
# TRONADURA TESORO NOR ESTE                          N/A
# TRONADURA TESORO SUR                        -59.144478
#
#
#
# Resumen para Gradient Boosting:
#                                           Diferencia %
# ADM OPERACIÓN Y GESTIÓN ESP                        N/A
# ADM OPERACIÓN Y GESTIÓN ESP SUR           29386.158796
# ADM OPERACIÓN Y GESTIÓN MIR                        N/A
# ADM OPERACIÓN Y GESTIÓN OXE                        N/A
# ADM OPERACIÓN Y GESTIÓN TC                14766.774199
# ADM OPERACIÓN Y GESTIÓN TES SUR                    N/A
# ADMINISTRACIÓN DESARROLLO MINA              -100.02642
# ADMINISTRACIÓN MINA                        -100.034635
# CARGUÍO                                    -249.413768
# CARGUÍO ENCUENTRO                           -110.21088
# CARGUÍO ESPERANZA                                  N/A
# CARGUÍO ESPERANZA SUR                              N/A
# CARGUÍO MIRADOR                                    N/A
# CARGUÍO TESORO CENTRAL                        3.000616
# CARGUÍO TESORO SUR                                 N/A
# EQUIPOS  AUXILIARES                        -166.824096
# EQUIPOS DE SOPORTE (APOYO)                 -128.621198
# MANTENIMIENTO MINA                          -46.502611
# MINA STRIPPING ESPERANZA                           N/A
# PERFORACIÓN                                -125.942057
# PERFORACIÓN ENCUENTRO                              N/A
# PERFORACIÓN ESPERANZA                       360.504121
# PERFORACIÓN ESPERANZA SUR                   -95.713593
# PERFORACIÓN MIRADOR                         -50.008592
# PERFORACIÓN TESORO CENTRAL                   -6.547835
# PERFORACIÓN TESORO NOR ESTE                        N/A
# PERFORACIÓN TESORO SUR                      -85.257152
# SERVICIOS DE APOYO MINA                    -111.955168
# SERVICIOS TERCEROS ESP                             N/A
# SERVICIOS TERCEROS ESP SUR                   -5.628481
# SERVICIOS TERCEROS LLANO                           N/A
# SERVICIOS TERCEROS MIR                       53.685703
# SERVICIOS TERCEROS OXE                      -55.670677
# SERVICIOS TERCEROS TC                              N/A
# SERVICIOS Y EQUIPOS DE APOYO ENCUENTRO             N/A
# SERVICIOS Y EQUIPOS DE APOYO ESP SUR         -82.71458
# SERVICIOS Y EQUIPOS DE APOYO ESPERANZA  1596013.075304
# SERVICIOS Y EQUIPOS DE APOYO MIRADOR               N/A
# SERVICIOS Y EQUIPOS DE APOYO TES SUR               N/A
# SERVICIOS Y EQUIPOS DE APOYO TESORO C.             N/A
# TRANSPORTE                                  -115.95029
# TRANSPORTE ENCUENTRO                               N/A
# TRANSPORTE ESPERANZA                               N/A
# TRANSPORTE ESPERANZA SUR                           N/A
# TRANSPORTE MIRADOR                                 N/A
# TRANSPORTE TESORO CENTRAL                          N/A
# TRANSPORTE TESORO SUR                              N/A
# TRONADURA ENCUENTRO                         -14.019367
# TRONADURA ESPERANZA                         -25.865817
# TRONADURA ESPERANZA SUR                     -95.852059
# TRONADURA MIRADOR                           -69.740215
# TRONADURA TESORO CENTRAL                    -13.709595
# TRONADURA TESORO NOR ESTE                          N/A
# TRONADURA TESORO SUR                        -95.423808
#
#
#
# Resumen para XGBoost:
#                                           Diferencia %
# ADM OPERACIÓN Y GESTIÓN ESP                        N/A
# ADM OPERACIÓN Y GESTIÓN ESP SUR           29386.157702
# ADM OPERACIÓN Y GESTIÓN MIR                        N/A
# ADM OPERACIÓN Y GESTIÓN OXE                        N/A
# ADM OPERACIÓN Y GESTIÓN TC                11808.405531
# ADM OPERACIÓN Y GESTIÓN TES SUR                    N/A
# ADMINISTRACIÓN DESARROLLO MINA             -100.026629
# ADMINISTRACIÓN MINA                        -100.032942
# CARGUÍO                                    -249.364598
# CARGUÍO ENCUENTRO                           -69.888745
# CARGUÍO ESPERANZA                                  N/A
# CARGUÍO ESPERANZA SUR                              N/A
# CARGUÍO MIRADOR                                    N/A
# CARGUÍO TESORO CENTRAL                       -7.863732
# CARGUÍO TESORO SUR                                 N/A
# EQUIPOS  AUXILIARES                        -167.883656
# EQUIPOS DE SOPORTE (APOYO)                 -126.370474
# MANTENIMIENTO MINA                          -62.593042
# MINA STRIPPING ESPERANZA                           N/A
# PERFORACIÓN                                -145.425326
# PERFORACIÓN ENCUENTRO                              N/A
# PERFORACIÓN ESPERANZA                       360.412198
# PERFORACIÓN ESPERANZA SUR                   -95.713593
# PERFORACIÓN MIRADOR                         -50.008592
# PERFORACIÓN TESORO CENTRAL                   -6.919748
# PERFORACIÓN TESORO NOR ESTE                        N/A
# PERFORACIÓN TESORO SUR                      -99.997371
# SERVICIOS DE APOYO MINA                    -111.960003
# SERVICIOS TERCEROS ESP                             N/A
# SERVICIOS TERCEROS ESP SUR                    1.869291
# SERVICIOS TERCEROS LLANO                           N/A
# SERVICIOS TERCEROS MIR                       79.302723
# SERVICIOS TERCEROS OXE                      -78.779276
# SERVICIOS TERCEROS TC                              N/A
# SERVICIOS Y EQUIPOS DE APOYO ENCUENTRO             N/A
# SERVICIOS Y EQUIPOS DE APOYO ESP SUR        -82.714581
# SERVICIOS Y EQUIPOS DE APOYO ESPERANZA  1603735.364226
# SERVICIOS Y EQUIPOS DE APOYO MIRADOR               N/A
# SERVICIOS Y EQUIPOS DE APOYO TES SUR               N/A
# SERVICIOS Y EQUIPOS DE APOYO TESORO C.             N/A
# TRANSPORTE                                 -113.303111
# TRANSPORTE ENCUENTRO                               N/A
# TRANSPORTE ESPERANZA                               N/A
# TRANSPORTE ESPERANZA SUR                           N/A
# TRANSPORTE MIRADOR                                 N/A
# TRANSPORTE TESORO CENTRAL                          N/A
# TRANSPORTE TESORO SUR                              N/A
# TRONADURA ENCUENTRO                          -22.19942
# TRONADURA ESPERANZA                         -25.865817
# TRONADURA ESPERANZA SUR                     -95.852059
# TRONADURA MIRADOR                           -69.740216
# TRONADURA TESORO CENTRAL                    -13.863587
# TRONADURA TESORO NOR ESTE                          N/A
# TRONADURA TESORO SUR                        -62.624066

# %%
import pandas as pd
import numpy as np

# Resultados de los modelos (simula los DataFrames que imprimiste anteriormente)
resultados = {
    'Linear Regression': resultados_lr_df,
    'Polynomial Regression': resultados_pr_df,
    'Neural Network': resultados_nn_df,
    'Random Forest': resultados_rf_df,
    'Gradient Boosting': resultados_gb_df,
    'XGBoost': resultados_xgb_df
}

# Crear un DataFrame para almacenar los mejores modelos para cada subproceso
mejor_modelo_df = pd.DataFrame(columns=['Subproceso', 'Mejor Modelo', 'Diferencia %'])

# Comparar los resultados para cada subproceso
for subproceso in resultados['Linear Regression'].index:
    mejor_modelo = None
    menor_diferencia = np.inf
    
    for modelo, df in resultados.items():
        if subproceso in df.index and df.loc[subproceso, 'Diferencia %'] != 'N/A':
            diferencia = abs(df.loc[subproceso, 'Diferencia %'])
            if diferencia < menor_diferencia:
                menor_diferencia = diferencia
                mejor_modelo = modelo
    
    # Guardar el mejor modelo para el subproceso
    nueva_fila = pd.DataFrame({
        'Subproceso': [subproceso],
        'Mejor Modelo': [mejor_modelo],
        'Diferencia %': [menor_diferencia]
    })
    
    mejor_modelo_df = pd.concat([mejor_modelo_df, nueva_fila], ignore_index=True)
    
# Exportar como Excel los resultados
mejor_modelo_df.to_excel('C:/Users/Administrator/Documents/GitHub/Hackathon2-2024/Desarollo/Resultados/Costos_Indicadores_Perforación_Imputacion.xlsx', index=False)

# Mostrar los resultados
mejor_modelo_df
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_6668\394072432.py:36: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   mejor_modelo_df = pd.concat([mejor_modelo_df, nueva_fila], ignore_index=True)
#                                 Subproceso           Mejor Modelo  \
# 0              ADM OPERACIÓN Y GESTIÓN ESP                   None
# 1          ADM OPERACIÓN Y GESTIÓN ESP SUR         Neural Network
# 2              ADM OPERACIÓN Y GESTIÓN MIR                   None
# 3              ADM OPERACIÓN Y GESTIÓN OXE                   None
# 4               ADM OPERACIÓN Y GESTIÓN TC                XGBoost
# 5          ADM OPERACIÓN Y GESTIÓN TES SUR                   None
# 6           ADMINISTRACIÓN DESARROLLO MINA         Neural Network
# 7                      ADMINISTRACIÓN MINA  Polynomial Regression
# 8                                  CARGUÍO         Neural Network
# 9                        CARGUÍO ENCUENTRO                XGBoost
# 10                       CARGUÍO ESPERANZA                   None
# 11                   CARGUÍO ESPERANZA SUR                   None
# 12                         CARGUÍO MIRADOR                   None
# 13                  CARGUÍO TESORO CENTRAL      Gradient Boosting
# 14                      CARGUÍO TESORO SUR                   None
# 15                     EQUIPOS  AUXILIARES         Neural Network
# 16              EQUIPOS DE SOPORTE (APOYO)         Neural Network
# 17                      MANTENIMIENTO MINA      Gradient Boosting
# 18                MINA STRIPPING ESPERANZA                   None
# 19                             PERFORACIÓN         Neural Network
# 20                   PERFORACIÓN ENCUENTRO                   None
# 21                   PERFORACIÓN ESPERANZA         Neural Network
# 22               PERFORACIÓN ESPERANZA SUR                XGBoost
# 23                     PERFORACIÓN MIRADOR                XGBoost
# 24              PERFORACIÓN TESORO CENTRAL      Linear Regression
# 25             PERFORACIÓN TESORO NOR ESTE                   None
# 26                  PERFORACIÓN TESORO SUR          Random Forest
# 27                 SERVICIOS DE APOYO MINA         Neural Network
# 28                  SERVICIOS TERCEROS ESP                   None
# 29              SERVICIOS TERCEROS ESP SUR                XGBoost
# 30                SERVICIOS TERCEROS LLANO                   None
# 31                  SERVICIOS TERCEROS MIR      Linear Regression
# 32                  SERVICIOS TERCEROS OXE          Random Forest
# 33                   SERVICIOS TERCEROS TC                   None
# 34  SERVICIOS Y EQUIPOS DE APOYO ENCUENTRO                   None
# 35    SERVICIOS Y EQUIPOS DE APOYO ESP SUR      Linear Regression
# 36  SERVICIOS Y EQUIPOS DE APOYO ESPERANZA         Neural Network
# 37    SERVICIOS Y EQUIPOS DE APOYO MIRADOR                   None
# 38    SERVICIOS Y EQUIPOS DE APOYO TES SUR                   None
# 39  SERVICIOS Y EQUIPOS DE APOYO TESORO C.                   None
# 40                              TRANSPORTE         Neural Network
# 41                    TRANSPORTE ENCUENTRO                   None
# 42                    TRANSPORTE ESPERANZA                   None
# 43                TRANSPORTE ESPERANZA SUR                   None
# 44                      TRANSPORTE MIRADOR                   None
# 45               TRANSPORTE TESORO CENTRAL                   None
# 46                   TRANSPORTE TESORO SUR                   None
# 47                     TRONADURA ENCUENTRO          Random Forest
# 48                     TRONADURA ESPERANZA                XGBoost
# 49                 TRONADURA ESPERANZA SUR                XGBoost
# 50                       TRONADURA MIRADOR      Linear Regression
# 51                TRONADURA TESORO CENTRAL  Polynomial Regression
# 52               TRONADURA TESORO NOR ESTE                   None
# 53                    TRONADURA TESORO SUR          Random Forest
#
#     Diferencia %
# 0            inf
# 1   2.464908e+02
# 2            inf
# 3            inf
# 4   1.180841e+04
# 5            inf
# 6   9.986430e+01
# 7   9.789313e+01
# 8   1.000092e+02
# 9   6.988875e+01
# 10           inf
# 11           inf
# 12           inf
# 13  3.000616e+00
# 14           inf
# 15  1.004663e+02
# 16  1.095721e+02
# 17  4.650261e+01
# 18           inf
# 19  1.004036e+02
# 20           inf
# 21  9.995009e+01
# 22  9.571359e+01
# 23  5.000859e+01
# 24  4.486075e+00
# 25           inf
# 26  4.525764e+01
# 27  1.000038e+02
# 28           inf
# 29  1.869291e+00
# 30           inf
# 31  3.156323e+01
# 32  3.824578e+01
# 33           inf
# 34           inf
# 35  8.271458e+01
# 36  7.684197e+01
# 37           inf
# 38           inf
# 39           inf
# 40  1.000305e+02
# 41           inf
# 42           inf
# 43           inf
# 44           inf
# 45           inf
# 46           inf
# 47  1.351328e+01
# 48  2.586582e+01
# 49  9.585206e+01
# 50  6.974022e+01
# 51  2.599806e+00
# 52           inf
# 53  5.914448e+01
